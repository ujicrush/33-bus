# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### multi & single

# %%
res_path = 'res/multi&single'

obj_2nd_ms = np.load(f"{res_path}/obj_2nd.npy")
lambda_2nd_ms = np.load(f"{res_path}/lambda_2nd.npy")
mu_2nd_ms = np.load(f"{res_path}/mu_2nd.npy")
previous_rating_ms = np.load(f"{res_path}/previous_rating.npy")
previous_cap_ms = np.load(f"{res_path}/previous_cap.npy")
ESS_loc_ms = np.load(f"{res_path}/ESS_loc.npy")
alpha_store_ms = np.load(f"{res_path}/alpha_store.npy")
upperB_save_ms = np.load(f"{res_path}/upperB_save.npy")
lowerB_save_ms = np.load(f"{res_path}/lowerB_save.npy")
invest_save_ms = np.load(f"{res_path}/invest_save.npy")
Elapsed_time_ms = np.load(f"{res_path}/Elapsed_time.npy")
total_time_ms = np.load(f"{res_path}/total_time.npy", allow_pickle=True)

print("obj_2nd shape:", obj_2nd_ms.shape)
print("lambda_2nd shape:", lambda_2nd_ms.shape)
print("mu_2nd shape:", mu_2nd_ms.shape)
print("previous_rating shape:", previous_rating_ms.shape)
print("previous_cap shape:", previous_cap_ms.shape)
print("ESS_loc shape:", ESS_loc_ms.shape)
print("alpha_store shape:", alpha_store_ms.shape)
print("upperB_save shape:", upperB_save_ms.shape)
print("lowerB_save shape:", lowerB_save_ms.shape)
print("invest_save shape:", invest_save_ms.shape)
print("Elapsed_time shape:", Elapsed_time_ms.shape)
print("total_time shape:", total_time_ms.shape)
# Out:
# obj_2nd shape: (12, 5)
# lambda_2nd shape: (12, 33, 24, 5)
# mu_2nd shape: (12, 33, 24, 5)
# previous_rating shape: (33, 5)
# previous_cap shape: (33, 5)
# ESS_loc shape: (33, 5)
# alpha_store shape: (5,)
# upperB_save shape: (5,)
# lowerB_save shape: (5,)
# invest_save shape: (5,)
# Elapsed_time shape: (5,)
# total_time shape: ()

# %%
iterations_ms = np.arange(len(upperB_save_ms))

plt.figure(figsize=(5, 3))
plt.plot(iterations_ms, upperB_save_ms, marker='o', label='Upper Bound', linewidth=2)
plt.plot(iterations_ms, lowerB_save_ms, marker='s', label='Lower Bound', linewidth=2)
plt.title("Convergence of Upper and Lower Bounds", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Convergence Process", fontsize=10)
plt.xticks(iterations_ms) 
plt.legend(fontsize=8)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.plot(iterations_ms, Elapsed_time_ms, marker='o', linewidth=2)
plt.title("Elapsed time for each iteration", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Time(s)", fontsize=10)
plt.xticks(iterations_ms) 
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
total_time_ms
# Out:
# array(datetime.timedelta(seconds=161, microseconds=279721), dtype=object)

# %% [markdown]
# ### multi

# %%
res_path = 'res/multi'

obj_2nd_m = np.load(f"{res_path}/obj_2nd.npy")
lambda_2nd_m = np.load(f"{res_path}/lambda_2nd.npy")
mu_2nd_m = np.load(f"{res_path}/mu_2nd.npy")
previous_rating_m = np.load(f"{res_path}/previous_rating.npy")
previous_cap_m = np.load(f"{res_path}/previous_cap.npy")
ESS_loc_m = np.load(f"{res_path}/ESS_loc.npy")
alpha_store_m = np.load(f"{res_path}/alpha_store.npy")
upperB_save_m = np.load(f"{res_path}/upperB_save.npy")
lowerB_save_m = np.load(f"{res_path}/lowerB_save.npy")
invest_save_m = np.load(f"{res_path}/invest_save.npy")
Elapsed_time_m = np.load(f"{res_path}/Elapsed_time.npy")
total_time_m = np.load(f"{res_path}/total_time.npy", allow_pickle=True)

print("obj_2nd shape:", obj_2nd_m.shape)
print("lambda_2nd shape:", lambda_2nd_m.shape)
print("mu_2nd shape:", mu_2nd_m.shape)
print("previous_rating shape:", previous_rating_m.shape)
print("previous_cap shape:", previous_cap_m.shape)
print("ESS_loc shape:", ESS_loc_m.shape)
print("alpha_store shape:", alpha_store_m.shape)
print("upperB_save shape:", upperB_save_m.shape)
print("lowerB_save shape:", lowerB_save_m.shape)
print("invest_save shape:", invest_save_m.shape)
print("Elapsed_time shape:", Elapsed_time_m.shape)
print("total_time shape:", total_time_m.shape)
# Out:
# obj_2nd shape: (12, 9)
# lambda_2nd shape: (12, 33, 24, 9)
# mu_2nd shape: (12, 33, 24, 9)
# previous_rating shape: (33, 9)
# previous_cap shape: (33, 9)
# ESS_loc shape: (33, 9)
# alpha_store shape: (12, 9)
# upperB_save shape: (9,)
# lowerB_save shape: (9,)
# invest_save shape: (9,)
# Elapsed_time shape: (9,)
# total_time shape: ()

# %%
iterations_m = np.arange(len(upperB_save_m))

plt.figure(figsize=(5, 3))
plt.plot(iterations_m, upperB_save_m, marker='o', label='Upper Bound', linewidth=2)
plt.plot(iterations_m, lowerB_save_m, marker='s', label='Lower Bound', linewidth=2)
plt.title("Convergence of Upper and Lower Bounds", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Convergence Process", fontsize=10)
plt.xticks(iterations_m) 
plt.legend(fontsize=8)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.plot(iterations_m, Elapsed_time_m, marker='o', linewidth=2)
plt.title("Elapsed time for each iteration", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Time(s)", fontsize=10)
plt.xticks(iterations_m) 
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
total_time_m
# Out:
# array(datetime.timedelta(seconds=285, microseconds=378611), dtype=object)

# %%
print(f"Power Rating(p.u.)")
print(f"N8:{previous_rating_m[7,8]}; N18:{previous_rating_m[17,8]}; N25:{previous_rating_m[24,8]};N33:{previous_rating_m[32,8]}")
# Out:
# Power Rating(p.u.)
# N8:1.6126286126785787e-06; N18:0.0; N25:0.0;N33:0.0

# %%
print(f"Capacity(p.u.)")
print(f"N8:{previous_cap_m[7,8]}; N18:{previous_cap_m[17,8]}; N25:{previous_cap_m[24,8]};N33:{previous_cap_m[32,8]}")
# Out:
# Capacity(p.u.)
# N8:1.6126286126785787e-06; N18:0.0; N25:0.0;N33:-6.162975822039155e-33

# %% [markdown]
# ### single

# %%
res_path = 'res/single'

obj_2nd_s = np.load(f"{res_path}/obj_2nd.npy")
lambda_2nd_s = np.load(f"{res_path}/lambda_2nd.npy")
mu_2nd_s = np.load(f"{res_path}/mu_2nd.npy")
previous_rating_s = np.load(f"{res_path}/previous_rating.npy")
previous_cap_s = np.load(f"{res_path}/previous_cap.npy")
ESS_loc_s = np.load(f"{res_path}/ESS_loc.npy")
alpha_store_s = np.load(f"{res_path}/alpha_store.npy")
upperB_save_s = np.load(f"{res_path}/upperB_save.npy")
lowerB_save_s = np.load(f"{res_path}/lowerB_save.npy")
invest_save_s = np.load(f"{res_path}/invest_save.npy")
Elapsed_time_s = np.load(f"{res_path}/Elapsed_time.npy")
total_time_s = np.load(f"{res_path}/total_time.npy", allow_pickle=True)

print("obj_2nd shape:", obj_2nd_s.shape)
print("lambda_2nd shape:", lambda_2nd_s.shape)
print("mu_2nd shape:", mu_2nd_s.shape)
print("previous_rating shape:", previous_rating_s.shape)
print("previous_cap shape:", previous_cap_s.shape)
print("ESS_loc shape:", ESS_loc_s.shape)
print("alpha_store shape:", alpha_store_s.shape)
print("upperB_save shape:", upperB_save_s.shape)
print("lowerB_save shape:", lowerB_save_s.shape)
print("invest_save shape:", invest_save_s.shape)
print("Elapsed_time shape:", Elapsed_time_s.shape)
print("total_time shape:", total_time_s.shape)
# Out:
# obj_2nd shape: (12, 9)
# lambda_2nd shape: (12, 33, 24, 9)
# mu_2nd shape: (12, 33, 24, 9)
# previous_rating shape: (33, 9)
# previous_cap shape: (33, 9)
# ESS_loc shape: (33, 9)
# alpha_store shape: (9,)
# upperB_save shape: (9,)
# lowerB_save shape: (9,)
# invest_save shape: (9,)
# Elapsed_time shape: (9,)
# total_time shape: ()

# %%
iterations_s = np.arange(len(upperB_save_s))

plt.figure(figsize=(5, 3))
plt.plot(iterations_s, upperB_save_s, marker='o', label='Upper Bound', linewidth=2)
plt.plot(iterations_s, lowerB_save_s, marker='s', label='Lower Bound', linewidth=2)
plt.title("Convergence of Upper and Lower Bounds", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Convergence Process", fontsize=10)
plt.xticks(iterations_s) 
plt.legend(fontsize=8)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.plot(iterations_s, Elapsed_time_s, marker='o', linewidth=2)
plt.title("Elapsed time for each iteration", fontsize=12)
plt.xlabel("Iteration", fontsize=10)
plt.ylabel("Time(s)", fontsize=10)
plt.xticks(iterations_s) 
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
total_time_s
# Out:
# array(datetime.timedelta(seconds=279, microseconds=683336), dtype=object)

# %%
print(f"Power Rating(p.u.)")
print(f"N8:{previous_rating_s[7,8]}; N18:{previous_rating_s[17,8]}; N25:{previous_rating_s[24,8]};N33:{previous_rating_s[32,8]}")
# Out:
# Power Rating(p.u.)
# N8:4.694238558951752e-07; N18:0.0; N25:0.0;N33:-2.465190328815662e-32

# %%
print(f"Capacity(p.u.)")
print(f"N8:{previous_cap_s[7,8]}; N18:{previous_cap_s[17,8]}; N25:{previous_cap_s[24,8]};N33:{previous_cap_s[32,8]}")
# Out:
# Capacity(p.u.)
# N8:4.694238558951752e-07; N18:0.0; N25:0.0;N33:0.0
